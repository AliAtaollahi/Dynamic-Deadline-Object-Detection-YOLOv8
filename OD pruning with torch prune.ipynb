# %% [markdown]
# # Dependencies

# %%
# !git clone https://github.com/VainF/Torch-Pruning
# Out:
# Cloning into 'Torch-Pruning'...
# remote: Enumerating objects: 6502, done.
# remote: Counting objects: 100% (389/389), done.
# remote: Compressing objects: 100% (203/203), done.
# remote: Total 6502 (delta 248), reused 292 (delta 185), pack-reused 6113
# Receiving objects: 100% (6502/6502), 9.87 MiB | 13.16 MiB/s, done.
# Resolving deltas: 100% (4300/4300), done.

# %%
# %cd Torch-Pruning/examples/yolov8/
# Out:
# /content/Torch-Pruning/examples/yolov8

# %%
# !git clone https://github.com/ultralytics/ultralytics.git
# %cp yolov8_pruning.py ultralytics/
# %cd ultralytics
# !git checkout 44c7c3514d87a5e05cfb14dba5a3eeb6eb860e70 # for compatibility
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 29435, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (39/39), done.
# remote: Total 29435 (delta 32), reused 56 (delta 28), pack-reused 29368
# Receiving objects: 100% (29435/29435), 14.97 MiB | 14.59 MiB/s, done.
# Resolving deltas: 100% (21195/21195), done.
# /content/Torch-Pruning/examples/yolov8/ultralytics
# Note: switching to '44c7c3514d87a5e05cfb14dba5a3eeb6eb860e70'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# ...

# %%
# !pip install torch_pruning thop
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.2/60.2 kB 2.6 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# ...

# %% [markdown]
# # Tests

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 5 --target-prune-rate 0.05 --max-map-drop 1
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 216MB/s]
# 2024-07-09 16:32:54.751732: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-09 16:32:54.751782: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-09 16:32:54.753183: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 185 layers, 3151904 parameters, 31936 gradients, 8.7 GFLOPs
#
# Dataset 'coco128.yaml' images not found ⚠️, missing paths ['/content/Torch-Pruning/examples/yolov8/datasets/coco128/images/train2017']
# ...

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 8 --target-prune-rate 0.1 --max-map-drop 1
# Out:
# 2024-07-09 16:45:56.841962: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-09 16:45:56.842018: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-09 16:45:56.843395: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 185 layers, 3151904 parameters, 31936 gradients, 8.7 GFLOPs
# val: Scanning /content/Torch-Pruning/examples/yolov8/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
# ...

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 9 --target-prune-rate 0.15 --max-map-drop 1
# Out:
# 2024-07-09 17:06:20.574392: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-09 17:06:20.574495: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-09 17:06:20.575984: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Ultralytics YOLOv8.0.90 🚀 Python-3.10.12 torch-2.3.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 185 layers, 3151904 parameters, 31936 gradients, 8.7 GFLOPs
# val: Scanning /content/Torch-Pruning/examples/yolov8/datasets/coco128/labels/train2017.cache... 126 images, 2 backgrounds, 0 corrupt: 100% 128/128 [00:00<?, ?it/s]
# ...

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 10 --target-prune-rate 0.2 --max-map-drop 1

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 10 --target-prune-rate 0.25 --max-map-drop 1

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 11 --target-prune-rate 0.3 --max-map-drop 1

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 12 --target-prune-rate 0.35 --max-map-drop 1

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 12 --target-prune-rate 0.4 --max-map-drop 1

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 12 --target-prune-rate 0.45 --max-map-drop 1

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 13 --target-prune-rate 0.5 --max-map-drop 1

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 13 --target-prune-rate 0.55 --max-map-drop 1

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 13 --target-prune-rate 0.6 --max-map-drop 1

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 13 --target-prune-rate 0.65 --max-map-drop 1

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 14 --target-prune-rate 0.7 --max-map-drop 1

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 14 --target-prune-rate 0.75 --max-map-drop 1

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 14 --target-prune-rate 0.8 --max-map-drop 1

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 14 --target-prune-rate 0.85 --max-map-drop 1

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 14 --target-prune-rate 0.9 --max-map-drop 1

# %%
# !python yolov8_pruning.py --model yolov8n.pt --iterative-steps 15 --target-prune-rate 0.95 --max-map-drop 1
